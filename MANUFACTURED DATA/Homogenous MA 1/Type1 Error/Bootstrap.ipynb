# %%
import numpy as np
import pandas as pd

def generate_staggered_law_ma1_data(N, T, theta, num_individuals, mean=0, std_dev=1):
    
    white_noise = np.random.normal(mean, std_dev, size=(N, num_individuals, T)) # generatingk random white noise for each individual

    data = np.zeros((N, num_individuals, T))  # Initializing the array to store the data

    # Including state and time effects 

    alphas = np.random.normal(0,1, size=N)
    betas = np.random.normal(0,1, size = T)

    # Generating the AR(1) process data for each individual

    for i in range(N):
        alpha = alphas[i]
        for j in range(num_individuals):
            for t in range(T):
                beta = betas[t]
                if t == 0:
                    data[i, j, t] = alpha + beta + white_noise[i, j, t]
                else:
                    data[i, j, t] = alpha + beta + theta * white_noise[i, j, t - 1] + white_noise[i, j, t]
    
    reshaped_data = data.reshape((N * num_individuals, T))  # Reshaping the data array for easier DataFrame creation

 
    df = pd.DataFrame(reshaped_data, columns=[f'{t}' for t in range(T)])    # Creating a DataFrame with column names as time periods

    
    df['state'] = np.repeat(np.arange(1, N + 1), num_individuals)  # Add a new 'state' column with repeated state values

    
    df['individual'] = np.tile(np.arange(1, num_individuals + 1), N)  # Add a new 'individual' column with repeated individual values


    melted_df = pd.melt(df, id_vars=['state', 'individual'], var_name='time', value_name= 'value') # to take the data in the long format

   
    melted_df['time'] = melted_df['time'].astype(int)   # Converting the 'time' column to int


    data = melted_df.copy()

    data['time'] = data['time'].astype(int)
    
    state_dummies = pd.get_dummies(data['state'], prefix='state', drop_first = True)  # Creating state dummy variables

   
    state_dummies = state_dummies.astype(int)  
  
    time_dummies = pd.get_dummies(data['time'].astype(int), prefix='time', drop_first = True)  # Creating time dummy variables

    time_dummies = time_dummies.astype(int)

    data = pd.concat([data, state_dummies, time_dummies], axis=1)

    return data

# %%
def calculate_standard_error(t_statistic, parameter_estimate):
    """
    Calculate the standard error given a t-statistic and the parameter estimate.
    
    Parameters:
    t_statistic (float): The t-statistic value.
    parameter_estimate (float): The estimated parameter value (e.g., mean difference).
    
    Returns:
    float: The calculated standard error.
    """
    if t_statistic == 0:
        raise ValueError("t_statistic cannot be zero.")
    return abs(parameter_estimate / t_statistic)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smp
from wildboottest.wildboottest import wildboottest
import warnings


alpha = 0.05  # Significance level
num_simulations = 1000
theta = 0.5
num_individuals = 1
N = 20
T = 20

reject_count = 0  # Counter for the number of rejections
true_beta1_value = 0   # Initialising the counters
bias_values = []
squared_error_values = []
standard_error_values =[]
beta1_estimates = []

np.random.seed(42) # setting seed for reproducibility


for _ in range(num_simulations):

    data = generate_staggered_law_ma1_data( N, T, theta, num_individuals) # this time the data generation is inside the loop to ensure everytime new data is generated

    states = data['state'].unique()
    
    treatment_states = np.random.choice(states, size=len(states)//2, replace=False)   # To give the treatment to exactly half the states in a staggered approach

    treatment_years = np.random.choice(range(5, 15), size=len(treatment_states), replace=True)  # Assigning treatment year to each treatment state, staggered between 5 and 15th time period

    state_to_treatment_year = dict(zip(treatment_states, treatment_years))

    # Adding a treatment column to the DataFrame
    
    data['TREATMENT'] = data.apply(lambda x: 1 if x['state'] in treatment_states and x['time'] >= state_to_treatment_year[x['state']] else 0, axis=1)

    model = smp.ols(formula="value ~ TREATMENT + 1 + state_2 + state_3 + state_4 + state_5 + state_6 + state_7 + state_8 + state_9 + state_10 + state_11 + state_12 + state_13 + state_14 + state_15 + state_16 + state_17 + state_18 + state_19 + time_1 + time_2 + time_3 + time_4 + time_5 + time_6 + time_7 + time_8 + time_9 + time_10 + time_11 + time_12 + time_13 + time_14 + time_15 + time_16 + time_17 + time_18 + time_19", data=data)

    result = model.fit()

    warnings.filterwarnings("ignore")

    wildboottest_results = wildboottest(model, param="TREATMENT", cluster=data['state'], B= 400, bootstrap_type='11', show = False)
    wildboottest_results = pd.DataFrame(wildboottest_results)
    p_value = wildboottest_results['p-value'].iloc[0]
    param = result.params['TREATMENT']
    t_stat = wildboottest_results['statistic'].iloc[0] 

    
    # Checking  if null hypothesis for beta1 is rejected

    if p_value < alpha:
        reject_count += 1

    beta1_estimates.append(param)
    
    bias = np.mean(beta1_estimates) - true_beta1_value

    squared_error = (param - true_beta1_value) ** 2
    squared_error_values.append(squared_error)

    # Extracting the standard error of the 'TREATMENT' coefficient 

    standard_error = calculate_standard_error(t_stat, param)
    standard_error_values.append(standard_error)


type1_error = reject_count/ num_simulations
bias = np.mean(bias)
mse = np.mean(squared_error_values)
rmse = np.sqrt(mse)
average_standard_error = np.mean(standard_error_values)


std_error_beta_distribution = np.std(beta1_estimates)  # Calculating the standard error of the distribution of beta

confidence_interval = (
    np.mean(beta1_estimates) - 1.96 * std_error_beta_distribution,
    np.mean(beta1_estimates) + 1.96 * std_error_beta_distribution
)


print(f"Number of times null hypothesis is rejected: {reject_count} out of {num_simulations} simulations")
print(f"Type 1 Error: {type1_error}")
print(f"Bias for Coefficient of Treatment : {bias}")
print(f"MSE for Coefficient of Treatment : {mse}")
print(f"RMSE for Coefficient of Treatment : {rmse}")
print(f"Average Standard Error: {average_standard_error}")
print(f"Standard Error of the beta_1 distribution: {std_error_beta_distribution}")
print(f'The confidence interval is {confidence_interval[0] , {confidence_interval[1]}}')

sns.histplot(beta1_estimates, kde = True)
plt.xlabel(r'$\beta_1$ Estimates')  # Using LaTeX for beta_1
plt.ylabel('Density')
plt.title(r'Distribution of $\beta_1$ Estimates')


mean_beta1_estimate = np.mean(beta1_estimates) # Calculating mean of beta1 estimates for marking on plot

# Adding vertical lines for the confidence interval and the mean beta1 estimate

plt.axvline(x=confidence_interval[0], color='red', linestyle='--', label='Lower CI')
plt.axvline(x=confidence_interval[1], color='green', linestyle='--', label='Upper CI')
plt.axvline(x=mean_beta1_estimate, color='blue', linestyle='-', label='Mean Beta1 Estimate')

plt.legend(loc='lower left', bbox_to_anchor=(1, 0))

plt.grid(True, which='both', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 50
#      46 result = model.fit()
#      48 warnings.filterwarnings("ignore")
# ---> 50 wildboottest_results = wildboottest(model, param="TREATMENT", cluster=data['state'], B= 400, bootstrap_type='11', show = False)
#      51 wildboottest_results = pd.DataFrame(wildboottest_results)
#      52 p_value = wildboottest_results['p-value'].iloc[0]
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\wildboottest\wildboottest.py:763, in wildboottest(model, B, cluster, param, weights_type, impose_null, bootstrap_type, seed, adj, cluster_adj, parallel, show)
#     761   param = xnames
#     762 elif isinstance(param, str):
# --> 763   pvalues, tstats, full_enumeration_warn = generate_stats(param, cluster=cluster)
#     764 else:
#     765   raise Exception("`param` not correctly specified")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\wildboottest\wildboottest.py:747, in wildboottest.<locals>.generate_stats(param, cluster)
#     745 _, _, full_enumeration_warn = boot.get_weights(weights_type = weights_type)
#     746 boot.get_numer()
# --> 747 boot.get_denom()
#     748 boot.get_tboot()
#     749 boot.get_vcov()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\wildboottest\wildboottest.py:551, in WildboottestCL.get_denom(self)
#     547       denom[b] = ssc * np.sum(np.power(Zg,2))
#     549     return denom
# --> 551   self.denom = compute_denom(self.Cg, H, self.bootclustid, self.B, self.G, self.v, self.ssc)
#     553 elif self.crv_type == "crv3":
#     555   self.inv_tXX_tXgXg = []
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:770, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     746 """Compiler entry point
#     747
#     748 Parameter
#    (...)
#     766     compiler pipeline
#     767 """
#     768 pipeline = pipeline_class(typingctx, targetctx, library,
#     769                           args, return_type, flags, locals)
# --> 770 return pipeline.compile_extra(func)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:461, in CompilerBase.compile_extra(self, func)
#     459 self.state.lifted = ()
#     460 self.state.lifted_from = None
# --> 461 return self._compile_bytecode()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:529, in CompilerBase._compile_bytecode(self)
#     525 """
#     526 Populate and run pipeline for bytecode input
#     527 """
#     528 assert self.state.func_ir is None
# --> 529 return self._compile_core()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:495, in CompilerBase._compile_core(self)
#     493 res = None
#     494 try:
# --> 495     pm.run(self.state)
#     496     if self.state.cr is not None:
#     497         break
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typed_passes.py:466, in BaseNativeLowering.run_pass(self, state)
#     463 with targetctx.push_code_library(library):
#     464     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     465                                 metadata=metadata)
# --> 466     lower.lower()
#     467     if not flags.no_cpython_wrapper:
#     468         lower.create_cpython_wrapper(flags.release_gil)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\lowering.py:187, in BaseLower.lower(self)
#     185 if self.generator_info is None:
#     186     self.genlower = None
# --> 187     self.lower_normal_function(self.fndesc)
#     188 else:
#     189     self.genlower = self.GeneratorLower(self)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\lowering.py:241, in BaseLower.lower_normal_function(self, fndesc)
#     239 # Init argument values
#     240 self.extract_function_arguments()
# --> 241 entry_block_tail = self.lower_function_body()
#     243 # Close tail of entry block, do not emit debug metadata else the
#     244 # unconditional jump gets associated with the metadata from the function
#     245 # body end.
#     246 with debuginfo.suspend_emission(self.builder):
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\lowering.py:271, in BaseLower.lower_function_body(self)
#     269     self.builder.position_at_end(bb)
#     270     self.debug_print(f"# lower block: {offset}")
# --> 271     self.lower_block(block)
#     272 self.post_lower()
#     273 return entry_block_tail
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\lowering.py:285, in BaseLower.lower_block(self, block)
#     282     defaulterrcls = partial(LoweringError, loc=self.loc)
#     283     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     284                            loc=self.loc, errcls_=defaulterrcls):
# --> 285         self.lower_inst(inst)
#     286 self.post_block(block)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\parfors\parfor_lowering.py:51, in ParforLower.lower_inst(self, inst)
#      49 def lower_inst(self, inst):
#      50     if isinstance(inst, parfor.Parfor):
# ---> 51         _lower_parfor_parallel(self, inst)
#      52     else:
#      53         super().lower_inst(inst)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\parfors\parfor_lowering.py:58, in _lower_parfor_parallel(lowerer, parfor)
#      56 def _lower_parfor_parallel(lowerer, parfor):
#      57     if parfor.lowerer is None:
# ---> 58         return _lower_parfor_parallel_std(lowerer, parfor)
#      59     else:
#      60         return parfor.lowerer(lowerer, parfor)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\parfors\parfor_lowering.py:340, in _lower_parfor_parallel_std(lowerer, parfor)
#     334 numba.parfors.parfor.sequential_parfor_lowering = True
#     335 try:
#     336     (func,
#     337      func_args,
#     338      func_sig,
#     339      func_arg_types,
# --> 340      exp_name_to_tuple_var) = _create_gufunc_for_parfor_body(
#     341         lowerer, parfor, typemap, typingctx, targetctx, flags, {},
#     342         bool(alias_map), index_var_typ, parfor.races)
#     343 finally:
#     344     numba.parfors.parfor.sequential_parfor_lowering = False
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\parfors\parfor_lowering.py:1548, in _create_gufunc_for_parfor_body(lowerer, parfor, typemap, typingctx, targetctx, flags, locals, has_aliases, index_var_typ, races)
#    1545         pm.finalize()
#    1546         return [pm]
# -> 1548 kernel_func = compiler.compile_ir(
#    1549     typingctx,
#    1550     targetctx,
#    1551     gufunc_ir,
#    1552     gufunc_param_types,
#    1553     types.none,
#    1554     flags,
#    1555     locals,
#    1556     pipeline_class=ParforGufuncCompiler)
#    1558 flags.noalias = old_alias
#    1560 kernel_sig = signature(types.none, *gufunc_param_types)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:833, in compile_ir(typingctx, targetctx, func_ir, args, return_type, flags, locals, lifted, lifted_from, is_lifted_loop, library, pipeline_class)
#     830 else:
#     831     pipeline = pipeline_class(typingctx, targetctx, library,
#     832                               args, return_type, flags, locals)
# --> 833     return pipeline.compile_ir(func_ir=func_ir, lifted=lifted,
#     834                                lifted_from=lifted_from)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:471, in CompilerBase.compile_ir(self, func_ir, lifted, lifted_from)
#     468 self.state.nargs = self.state.func_ir.arg_count
#     470 FixupArgs().run_pass(self.state)
# --> 471 return self._compile_ir()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:536, in CompilerBase._compile_ir(self)
#     532 """
#     533 Populate and run pipeline for IR input
#     534 """
#     535 assert self.state.func_ir is not None
# --> 536 return self._compile_core()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:495, in CompilerBase._compile_core(self)
#     493 res = None
#     494 try:
# --> 495     pm.run(self.state)
#     496     if self.state.cr is not None:
#     497         break
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typed_passes.py:110, in BaseTypeInference.run_pass(self, state)
#     104 """
#     105 Type inference and legalization
#     106 """
#     107 with fallback_context(state, 'Function "%s" failed type inference'
#     108                       % (state.func_id.func_name,)):
#     109     # Type inference
# --> 110     typemap, return_type, calltypes, errs = type_inference_stage(
#     111         state.typingctx,
#     112         state.targetctx,
#     113         state.func_ir,
#     114         state.args,
#     115         state.return_type,
#     116         state.locals,
#     117         raise_errors=self._raise_errors)
#     118     state.typemap = typemap
#     119     # save errors in case of partial typing
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typed_passes.py:91, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      89     infer.build_constraint()
#      90     # return errors in case of partial typing
# ---> 91     errs = infer.propagate(raise_errors=raise_errors)
#      92     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      94 return _TypingResults(typemap, restype, calltypes, errs)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typeinfer.py:1078, in TypeInferer.propagate(self, raise_errors)
#    1075 oldtoken = newtoken
#    1076 # Errors can appear when the type set is incomplete; only
#    1077 # raise them when there is no progress anymore.
# -> 1078 errors = self.constraints.propagate(self)
#    1079 newtoken = self.get_state_token()
#    1080 self.debug.propagate_finished()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typeinfer.py:155, in ConstraintNetwork.propagate(self, typeinfer)
#     152 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     153                                        lineno=loc.line):
#     154     try:
# --> 155         constraint(typeinfer)
#     156     except ForceLiteralArg as e:
#     157         errors.append(e)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typeinfer.py:578, in CallConstraint.__call__(self, typeinfer)
#     576     fnty = typevars[self.func].getone()
#     577 with new_error_context("resolving callee type: {0}", fnty):
# --> 578     self.resolve(typeinfer, typevars, fnty)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typeinfer.py:601, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     599     fnty = fnty.instance_type
#     600 try:
# --> 601     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     602 except ForceLiteralArg as e:
#     603     # Adjust for bound methods
#     604     folding_args = ((fnty.this,) + tuple(self.args)
#     605                     if isinstance(fnty, types.BoundFunction)
#     606                     else self.args)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typeinfer.py:1557, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1554     return sig
#    1555 else:
#    1556     # Normal non-recursive call
# -> 1557     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typing\context.py:196, in BaseContext.resolve_function_type(self, func, args, kws)
#     194 # Prefer user definition first
#     195 try:
# --> 196     res = self._resolve_user_function_type(func, args, kws)
#     197 except errors.TypingError as e:
#     198     # Capture any typing error
#     199     last_exception = e
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typing\context.py:248, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     244         return self.resolve_function_type(func_type, args, kws)
#     246 if isinstance(func, types.Callable):
#     247     # XXX fold this into the __call__ attribute logic?
# --> 248     return func.get_call_type(self, args, kws)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\types\functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if (utils.use_new_style_errors() and not
#     311             isinstance(e, errors.NumbaError)):
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typing\templates.py:351, in AbstractTemplate.apply(self, args, kws)
#     349 def apply(self, args, kws):
#     350     generic = getattr(self, "generic")
# --> 351     sig = generic(args, kws)
#     352     # Enforce that *generic()* must return None or Signature
#     353     if sig is not None:
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typing\templates.py:614, in _OverloadFunctionTemplate.generic(self, args, kws)
#     608 """
#     609 Type the overloaded function by compiling the appropriate
#     610 implementation for the given args.
#     611 """
#     612 from numba.core.typed_passes import PreLowerStripPhis
# --> 614 disp, new_args = self._get_impl(args, kws)
#     615 if disp is None:
#     616     return
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typing\templates.py:713, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     709 except KeyError:
#     710     # pass and try outside the scope so as to not have KeyError with a
#     711     # nested addition error in the case the _build_impl fails
#     712     pass
# --> 713 impl, args = self._build_impl(cache_key, args, kws)
#     714 return impl, args
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typing\templates.py:817, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     815 # Make sure that the implementation can be fully compiled
#     816 disp_type = types.Dispatcher(disp)
# --> 817 disp_type.get_call_type(self.context, args, kws)
#     818 if cache_key is not None:
#     819     self._impl_cache[cache_key] = disp, args
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\types\functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:363, in _DispatcherBase.get_call_template(self, args, kws)
#     361 # Ensure an overload is available
#     362 if self._can_compile:
# --> 363     self.compile(tuple(args))
#     365 # Create function type for typing
#     366 func_name = self.py_func.__name__
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:770, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     746 """Compiler entry point
#     747
#     748 Parameter
#    (...)
#     766     compiler pipeline
#     767 """
#     768 pipeline = pipeline_class(typingctx, targetctx, library,
#     769                           args, return_type, flags, locals)
# --> 770 return pipeline.compile_extra(func)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:461, in CompilerBase.compile_extra(self, func)
#     459 self.state.lifted = ()
#     460 self.state.lifted_from = None
# --> 461 return self._compile_bytecode()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:529, in CompilerBase._compile_bytecode(self)
#     525 """
#     526 Populate and run pipeline for bytecode input
#     527 """
#     528 assert self.state.func_ir is None
# --> 529 return self._compile_core()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler.py:495, in CompilerBase._compile_core(self)
#     493 res = None
#     494 try:
# --> 495     pm.run(self.state)
#     496     if self.state.cr is not None:
#     497         break
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\typed_passes.py:438, in BaseNativeLowering.run_pass(self, state)
#     436 if state.library is None:
#     437     codegen = state.targetctx.codegen()
# --> 438     state.library = codegen.create_library(state.func_id.func_qualname)
#     439     # Enable object caching upfront, so that the library can
#     440     # be later serialized.
#     441     state.library.enable_object_caching()
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\codegen.py:1155, in Codegen.create_library(self, name, **kwargs)
#    1150 def create_library(self, name, **kwargs):
#    1151     """
#    1152     Create a :class:`CodeLibrary` object for use with this codegen
#    1153     instance.
#    1154     """
# -> 1155     return self._library_class(self, name, **kwargs)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\codegen.py:647, in CPUCodeLibrary.__init__(self, codegen, name)
#     644 super().__init__(codegen, name)
#     645 self._linking_libraries = []   # maintain insertion order
#     646 self._final_module = ll.parse_assembly(
# --> 647     str(self._codegen._create_empty_module(self.name)))
#     648 self._final_module.name = cgutils.normalize_ir_text(self.name)
#     649 self._shared_module = None
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\numba\core\codegen.py:1221, in CPUCodegen._create_empty_module(self, name)
#    1219 def _create_empty_module(self, name):
#    1220     ir_module = llvmir.Module(cgutils.normalize_ir_text(name))
# -> 1221     ir_module.triple = ll.get_process_triple()
#    1222     if self._data_layout:
#    1223         ir_module.data_layout = self._data_layout
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\llvmlite\binding\targets.py:17, in get_process_triple()
#      10 """
#      11 Return a target triple suitable for generating code for the current process.
#      12 An example when the default triple from ``get_default_triple()`` is not be
#      13 suitable is when LLVM is compiled for 32-bit but the process is executing
#      14 in 64-bit mode.
#      15 """
#      16 with ffi.OutputString() as out:
# ---> 17     ffi.lib.LLVMPY_GetProcessTriple(out)
#      18     return str(out)
#
# File c:\Users\sneha\.ipynb_checkpoints\.conda\lib\site-packages\llvmlite\binding\ffi.py:190, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     188 def __call__(self, *args, **kwargs):
#     189     with self._lock:
# --> 190         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:
