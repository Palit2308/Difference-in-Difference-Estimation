# %%
file_path = r'C:\Users\sneha\Downloads\cps_00006.csv.gz' # path for the data, needs to be changed accordingly

# %%
num_of_states = 50     # this needs be changed to the desired number of states

# %%
import pandas as pd
import numpy as np
import gzip

# data preperation code

def cps_data(file_path):
  
    df = pd.read_csv(file_path, compression='gzip', header=0) # importing the data

    
    df = df[(df['INCWAGE'] != 99999999) & (df['INCWAGE'] != 0) & (df['INCWAGE'] != 999)]  # dropping the rows containing invalid and 0 INCWAGE according to the labels

    df['INCWAGE'] = np.log(df['INCWAGE'])  # taking log of weekly earnings which will be our dependent variable in the regressions


    df = df[(df['EDUC'] != 0) & (df['EDUC'] != 1)]  # dropping education levels 0 and 1 as they are invalid entries as per the labels of the dataset

    df = df[(df['YEAR'] >= 1980) & (df['YEAR'] <= 2000)]  # taking the time frame from 1980 to 2000

    def categorize_education(educ_code): # creating a fucntion to categorize education levels
        if educ_code <= 10:
            return 'Up to Grade 10'
        elif 10 < educ_code <= 70:
            return 'High School'
        elif 70 < educ_code <= 123:
            return "Master's Degree"
        else:
            return 'Doctorate Degree'

    
    df['Education_Category'] = df['EDUC'].apply(categorize_education) # applying the function to create a new 'Education_Category' column

    df = pd.get_dummies(df, columns=['Education_Category'], prefix='', prefix_sep='', drop_first=True)

    boolean = ['Up to Grade 10', 'High School', "Master's Degree"]
    df[boolean] = df[boolean].astype(int)

    df = df[~((df['STATEFIP'] > 56) | (df['STATEFIP'] == 11))]  # taking only the 50 states of the States and exclusing the regions as per the labels of the dataset

    df = df[(df['AGE'] >= 25) & (df['AGE'] <= 50)]  # taking the age group from 25 to 50

    df = df[df['SEX'] == 2] # taking only female respondents

    return df

# %%
import statsmodels.api as sm

# data aggregation code

def process_cps_data(file_path):

    df = cps_data(file_path)

    X = df[['High School', "Master's Degree", 'Up to Grade 10', 'AGE']] # the covariates used 1st stage of data aggregation
    y = df['INCWAGE']

    X = sm.add_constant(X)

    model = sm.OLS(y, X).fit()

    y_pred = model.predict(X)  # obtaining the predicted values of the model

    residuals = y - y_pred

    df['Residuals'] = residuals

    residuals_mean_by_state_year = df.groupby(['STATEFIP', 'YEAR'])['Residuals'].mean().reset_index()

    residuals_mean_by_state_year 

    return residuals_mean_by_state_year

# %%
# the function is necessary to extract the standard error values from the wildboottest result table

def calculate_standard_error(t_statistic, parameter_estimate):
    """
    Calculate the standard error given a t-statistic and the parameter estimate.
    
    Parameters:
    t_statistic (float): The t-statistic value.
    parameter_estimate (float): The estimated parameter value (e.g., mean difference).
    
    Returns:
    float: The calculated standard error.
    """
    if t_statistic == 0:
        raise ValueError("t_statistic cannot be zero.")
    return abs(parameter_estimate / t_statistic)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smp
from wildboottest.wildboottest import wildboottest
import warnings


alpha = 0.05  # Significance level
num_simulations = 1000

reject_count = 0  # Counter for the number of rejections
true_beta1_value = 0   # Initialising the counters
bias_values = []
squared_error_values = []
standard_error_values =[]
beta1_estimates = []

np.random.seed(42) # setting seed for reproducibility

df = process_cps_data(file_path)  # importing the data from process_cps_data module

for _ in range(num_simulations):

    data = df.copy()

    unique_statefips = data['STATEFIP'].unique()
    selected_statefips = np.random.choice(unique_statefips, size=num_of_states, replace=False)

    # Filter the DataFrame to only include rows with the selected STATEFIPs
    data = data[data['STATEFIP'].isin(selected_statefips)]
    
    states = data['STATEFIP'].unique()
    
    # Randomly selecting  half of the states to be in the treatment group
    
    treatment_states = np.random.choice(states, size=len(states)//2, replace=False)

    # Assigning treatment year to each treatment state, staggered between 1985 and 1995

    treatment_years = np.random.choice(range(1985, 1995), size=len(treatment_states), replace=True)
    state_to_treatment_year = dict(zip(treatment_states, treatment_years))

    # Adding a treatment column to the DataFrame

    data['TREATMENT'] = data.apply(lambda x: 1 if x['STATEFIP'] in treatment_states and x['YEAR'] >= state_to_treatment_year[x['STATEFIP']] else 0, axis=1)
  
    dummy_df = pd.get_dummies(data['STATEFIP'], prefix='STATEFIP', drop_first=True).astype(int)

    # Concatenate the dummy variables with the original DataFrame
    data = pd.concat([data, dummy_df], axis=1)

    dummy_df2 = pd.get_dummies(data['YEAR'], prefix='YEAR', drop_first=True).astype(int)

    # Concatenate the dummy variables with the original DataFrame
    data = pd.concat([data, dummy_df2], axis=1)

    columns_to_exclude = ['STATEFIP', 'YEAR', 'Residuals']

    warnings.filterwarnings("ignore")

    X_columns =[col for col in data.columns if col not in columns_to_exclude]

    formula = "Residuals ~ "
    
    formula += " + ".join(X_columns)

    model = smp.ols(formula = formula , data = data)

    
    result = model.fit()
    wildboottest_results = wildboottest(model, param="TREATMENT", cluster=data['STATEFIP'], B= 400, bootstrap_type='11', show = False)
    wildboottest_results = pd.DataFrame(wildboottest_results)
    p_value = wildboottest_results['p-value'].iloc[0]
    param = result.params['TREATMENT']
    t_stat = wildboottest_results['statistic'].iloc[0] 

    
    # Checking  if null hypothesis for beta1 is rejected

    if p_value < alpha:
        reject_count += 1

    beta1_estimates.append(param)
    
    bias = np.mean(beta1_estimates) - true_beta1_value

    squared_error = (param - true_beta1_value) ** 2
    squared_error_values.append(squared_error)

    # Extracting the standard error of the 'TREATMENT' coefficient 

    standard_error = calculate_standard_error(t_stat, param)
    standard_error_values.append(standard_error)


type1_error = reject_count/ num_simulations
bias = np.mean(bias)
mse = np.mean(squared_error_values)
rmse = np.sqrt(mse)
average_standard_error = np.mean(standard_error_values)


std_error_beta_distribution = np.std(beta1_estimates)  # Calculating the standard error of the distribution of beta

confidence_interval = (
    np.mean(beta1_estimates) - 1.96 * std_error_beta_distribution,
    np.mean(beta1_estimates) + 1.96 * std_error_beta_distribution
)


print(f"Number of times null hypothesis is rejected: {reject_count} out of {num_simulations} simulations")
print(f"Type 1 Error: {type1_error}")
print(f"Bias for Coefficient of Treatment : {bias}")
print(f"MSE for Coefficient of Treatment : {mse}")
print(f"RMSE for Coefficient of Treatment : {rmse}")
print(f"Average Standard Error: {average_standard_error}")
print(f"Standard Error of the beta_1 distribution: {std_error_beta_distribution}")
print(f'The confidence interval is {confidence_interval[0] , {confidence_interval[1]}}')

sns.histplot(beta1_estimates, kde = True)
plt.xlabel(r'$\beta_1$ Estimates')  
plt.ylabel('Density')
plt.title(r'Distribution of $\beta_1$ Estimates')


mean_beta1_estimate = np.mean(beta1_estimates) # Calculating mean of beta1 estimates for marking on plot

# Adding vertical lines for the confidence interval and the mean beta1 estimate

plt.axvline(x=confidence_interval[0], color='red', linestyle='--', label='Lower CI')
plt.axvline(x=confidence_interval[1], color='green', linestyle='--', label='Upper CI')
plt.axvline(x=mean_beta1_estimate, color='blue', linestyle='-', label='Mean Beta1 Estimate')

plt.legend(loc='lower left', bbox_to_anchor=(1, 0))

plt.grid(True, which='both', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 74
#      70 model = smp.ols(formula = formula , data = data)
#      73 result = model.fit()
# ---> 74 wildboottest_results = wildboottest(model, param="TREATMENT", cluster=data['STATEFIP'], B= 400, bootstrap_type='11', show = False)
#      75 wildboottest_results = pd.DataFrame(wildboottest_results)
#      76 p_value = wildboottest_results['p-value'].iloc[0]
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\wildboottest\wildboottest.py:763, in wildboottest(model, B, cluster, param, weights_type, impose_null, bootstrap_type, seed, adj, cluster_adj, parallel, show)
#     761   param = xnames
#     762 elif isinstance(param, str):
# --> 763   pvalues, tstats, full_enumeration_warn = generate_stats(param, cluster=cluster)
#     764 else:
#     765   raise Exception("`param` not correctly specified")
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\wildboottest\wildboottest.py:747, in wildboottest.<locals>.generate_stats(param, cluster)
#     745 _, _, full_enumeration_warn = boot.get_weights(weights_type = weights_type)
#     746 boot.get_numer()
# --> 747 boot.get_denom()
#     748 boot.get_tboot()
#     749 boot.get_vcov()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\wildboottest\wildboottest.py:551, in WildboottestCL.get_denom(self)
#     547       denom[b] = ssc * np.sum(np.power(Zg,2))
#     549     return denom
# --> 551   self.denom = compute_denom(self.Cg, H, self.bootclustid, self.B, self.G, self.v, self.ssc)
#     553 elif self.crv_type == "crv3":
#     555   self.inv_tXX_tXgXg = []
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler.py:770, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     746 """Compiler entry point
#     747
#     748 Parameter
#    (...)
#     766     compiler pipeline
#     767 """
#     768 pipeline = pipeline_class(typingctx, targetctx, library,
#     769                           args, return_type, flags, locals)
# --> 770 return pipeline.compile_extra(func)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler.py:461, in CompilerBase.compile_extra(self, func)
#     459 self.state.lifted = ()
#     460 self.state.lifted_from = None
# --> 461 return self._compile_bytecode()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler.py:529, in CompilerBase._compile_bytecode(self)
#     525 """
#     526 Populate and run pipeline for bytecode input
#     527 """
#     528 assert self.state.func_ir is None
# --> 529 return self._compile_core()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler.py:495, in CompilerBase._compile_core(self)
#     493 res = None
#     494 try:
# --> 495     pm.run(self.state)
#     496     if self.state.cr is not None:
#     497         break
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\typed_passes.py:466, in BaseNativeLowering.run_pass(self, state)
#     463 with targetctx.push_code_library(library):
#     464     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     465                                 metadata=metadata)
# --> 466     lower.lower()
#     467     if not flags.no_cpython_wrapper:
#     468         lower.create_cpython_wrapper(flags.release_gil)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\lowering.py:187, in BaseLower.lower(self)
#     185 if self.generator_info is None:
#     186     self.genlower = None
# --> 187     self.lower_normal_function(self.fndesc)
#     188 else:
#     189     self.genlower = self.GeneratorLower(self)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\lowering.py:241, in BaseLower.lower_normal_function(self, fndesc)
#     239 # Init argument values
#     240 self.extract_function_arguments()
# --> 241 entry_block_tail = self.lower_function_body()
#     243 # Close tail of entry block, do not emit debug metadata else the
#     244 # unconditional jump gets associated with the metadata from the function
#     245 # body end.
#     246 with debuginfo.suspend_emission(self.builder):
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\lowering.py:271, in BaseLower.lower_function_body(self)
#     269     self.builder.position_at_end(bb)
#     270     self.debug_print(f"# lower block: {offset}")
# --> 271     self.lower_block(block)
#     272 self.post_lower()
#     273 return entry_block_tail
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\lowering.py:285, in BaseLower.lower_block(self, block)
#     282     defaulterrcls = partial(LoweringError, loc=self.loc)
#     283     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     284                            loc=self.loc, errcls_=defaulterrcls):
# --> 285         self.lower_inst(inst)
#     286 self.post_block(block)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\parfors\parfor_lowering.py:51, in ParforLower.lower_inst(self, inst)
#      49 def lower_inst(self, inst):
#      50     if isinstance(inst, parfor.Parfor):
# ---> 51         _lower_parfor_parallel(self, inst)
#      52     else:
#      53         super().lower_inst(inst)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\parfors\parfor_lowering.py:58, in _lower_parfor_parallel(lowerer, parfor)
#      56 def _lower_parfor_parallel(lowerer, parfor):
#      57     if parfor.lowerer is None:
# ---> 58         return _lower_parfor_parallel_std(lowerer, parfor)
#      59     else:
#      60         return parfor.lowerer(lowerer, parfor)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\parfors\parfor_lowering.py:372, in _lower_parfor_parallel_std(lowerer, parfor)
#     370     print("loop_nests = ", parfor.loop_nests)
#     371     print("loop_ranges = ", loop_ranges)
# --> 372 call_parallel_gufunc(
#     373     lowerer,
#     374     func,
#     375     gu_signature,
#     376     func_sig,
#     377     func_args,
#     378     func_arg_types,
#     379     loop_ranges,
#     380     parfor_redvars,
#     381     parfor_reddict,
#     382     redarrs,
#     383     parfor.init_block,
#     384     index_var_typ,
#     385     parfor.races,
#     386     exp_name_to_tuple_var)
#     388 if nredvars > 0:
#     389     _parfor_lowering_finalize_reduction(
#     390         parfor, redarrs, lowerer, parfor_reddict, num_threads_var,
#     391     )
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\parfors\parfor_lowering.py:1634, in call_parallel_gufunc(lowerer, cres, gu_signature, outer_sig, expr_args, expr_arg_types, loop_ranges, redvars, reddict, redarrdict, init_block, index_var_typ, races, exp_name_to_tuple_var)
#    1631 # These are necessary for build_gufunc_wrapper to find external symbols
#    1632 _launch_threads()
# -> 1634 info = build_gufunc_wrapper(llvm_func, cres, sin, sout,
#    1635                             cache=False, is_parfors=True)
#    1636 wrapper_name = info.name
#    1637 cres.library._ensure_finalized()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\np\ufunc\parallel.py:271, in build_gufunc_wrapper(py_func, cres, sin, sout, cache, is_parfors)
#     268 sym_out = set(sym for term in sout for sym in term)
#     269 inner_ndim = len(sym_in | sym_out)
# --> 271 info = build_gufunc_kernel(
#     272     library, ctx, innerinfo, signature, inner_ndim,
#     273 )
#     274 return info
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\np\ufunc\parallel.py:152, in build_gufunc_kernel(library, ctx, info, sig, inner_ndim)
#     146 innerfunc_fnty = ir.FunctionType(
#     147     ir.VoidType(),
#     148     [byte_ptr_ptr_t, intp_ptr_t, intp_ptr_t, byte_ptr_t],
#     149 )
#     150 tmp_voidptr = cgutils.get_or_insert_function(mod, innerfunc_fnty,
#     151                                              info.name,)
# --> 152 wrapperlib.add_linking_library(info.library)
#     154 get_num_threads = cgutils.get_or_insert_function(
#     155     builder.module,
#     156     ir.FunctionType(ir.IntType(types.intp.bitwidth), []),
#     157     "get_num_threads")
#     159 num_threads = builder.call(get_num_threads, [])
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\codegen.py:720, in CPUCodeLibrary.add_linking_library(self, library)
#     719 def add_linking_library(self, library):
# --> 720     library._ensure_finalized()
#     721     self._linking_libraries.append(library)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\codegen.py:567, in CodeLibrary._ensure_finalized(self)
#     565 def _ensure_finalized(self):
#     566     if not self._finalized:
# --> 567         self.finalize()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\numba\core\codegen.py:756, in CPUCodeLibrary.finalize(self)
#     754     if library not in seen:
#     755         seen.add(library)
# --> 756         self._final_module.link_in(
#     757             library._get_module_for_linking(), preserve=True,
#     758         )
#     760 # Optimize the module after all dependences are linked in above,
#     761 # to allow for inlining.
#     762 self._optimize_final_module()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\llvmlite\binding\module.py:174, in ModuleRef.link_in(self, other, preserve)
#     172 if preserve:
#     173     other = other.clone()
# --> 174 link_modules(self, other)
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\llvmlite\binding\linker.py:7, in link_modules(dst, src)
#       5 def link_modules(dst, src):
#       6     with ffi.OutputString() as outerr:
# ----> 7         err = ffi.lib.LLVMPY_LinkModules(dst, src, outerr)
#       8         # The underlying module was destroyed
#       9         src.detach()
#
# File c:\Users\sneha\anaconda3\Lib\site-packages\llvmlite\binding\ffi.py:190, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     188 def __call__(self, *args, **kwargs):
#     189     with self._lock:
# --> 190         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:
